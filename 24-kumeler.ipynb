# %%
kume = set()

# %%
type(kume)
# Out:
# set

# %%
kume1 = set(['elma', 'armut', 'kiraz'])

# %%
kume1
# Out:
# {'armut', 'elma', 'kiraz'}

# %%
string = 'Python Programlama Dili'
str_kume = set(string)

# %%
str_kume
# Out:
# {' ', 'D', 'P', 'a', 'g', 'h', 'i', 'l', 'm', 'n', 'o', 'r', 't', 'y'}

# %%
kume3 = {'Python', 'C', 'C++'}

# %%
type(kume3)
# Out:
# set

# %%
sozluk = {"işletim sistemi": "GNU",
            "sistem çekirdeği": "Linux",
            "dağıtım": "Ubuntu GNU/Linux"}

# %%
kume = set(sozluk)

# %%
kume
# Out:
# {'dağıtım', 'işletim sistemi', 'sistem çekirdeği'}

# %%
liste = [(key,value) for key, value in sozluk.items()]
print(set(liste))
# Out:
# {('işletim sistemi', 'GNU'), ('sistem çekirdeği', 'Linux'), ('dağıtım', 'Ubuntu GNU/Linux')}

# %%
liste= ["elma","armut", "elma","kebap", "şeker","armut",
        "çilek", "ağaç", "şeker", "kebap", "şeker"]
for i in set(liste):
    print(i)
# Out:
# şeker
# ağaç
# elma
# çilek
# armut
# kebap

# %%
for i in set(liste):
    print("{} listede {} defa geçiyor".format(i, liste.count(i)))
# Out:
# şeker listede 3 defa geçiyor
# ağaç listede 1 defa geçiyor
# elma listede 2 defa geçiyor
# çilek listede 1 defa geçiyor
# armut listede 2 defa geçiyor
# kebap listede 2 defa geçiyor

# %% [markdown]
# # Küme Üreteçleri

# %%
import random

# %%
liste = [random.randint(0,1000) for i in range(1000)]

# %%
küme = {i for i in liste if i<100}

# %%
küme
# Out:
# {0,
#  1,
#  2,
#  4,
#  5,
#  8,
#  9,
#  12,
#  13,
#  15,
#  16,
#  17,
#  18,
#  20,
#  22,
#  23,
#  24,
#  25,
#  26,
#  27,
#  28,
#  30,
#  31,
#  32,
#  33,
#  34,
#  36,
#  39,
#  40,
#  41,
#  42,
#  43,
#  44,
#  46,
#  47,
#  48,
#  49,
#  50,
#  52,
#  53,
#  54,
#  56,
#  58,
#  59,
#  62,
#  63,
#  66,
#  68,
#  71,
#  72,
#  73,
#  75,
#  77,
#  78,
#  79,
#  82,
#  83,
#  85,
#  87,
#  90,
#  91,
#  92,
#  94,
#  95,
#  97}

# %% [markdown]
# # Kümelerin Metotları

# %%
[i for i in dir(set) if not i.startswith('__')]
# Out:
# ['add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
kume
# Out:
# {'dağıtım', 'işletim sistemi', 'sistem çekirdeği'}

# %%
kume.clear()

# %%
kume
# Out:
# set()

# %%
kume = set('Adana')

# %%
kume2 = kume.copy()

# %%
kume
# Out:
# {'A', 'a', 'd', 'n'}

# %%
kume2
# Out:
# {'A', 'a', 'd', 'n'}

# %%
kume.add('Z')

# %%
kume
# Out:
# {'A', 'Z', 'a', 'd', 'n'}

# %%
kume2
# Out:
# {'A', 'a', 'd', 'n'}

# %%
k1 = {random.randint(1,20) for i in range(10)}
k2 = {random.randint(1,20) for i in range(10)}

# %%
k1.difference(k2)
# Out:
# {4, 5, 12, 15, 18}

# %%
k1-k2
# Out:
# {4, 5, 12, 15, 18}

# %%
k1.difference_update(k2)

# %%
k1
# Out:
# {4, 5, 12, 15, 18}

# %%
k1.discard(18)

# %%
k1
# Out:
# {4, 5, 12, 15}

# %%
k1.remove(4)

# %%
k1
# Out:
# {5, 12, 15}

# %%
k1 = {random.randint(1,20) for i in range(10)}
k2 = {random.randint(1,20) for i in range(10)}

# %%
k1.intersection(k2)
# Out:
# {8, 11, 16}

# %%
k1 & k2
# Out:
# {8, 11, 16}

# %%
k1
# Out:
# {1, 2, 5, 6, 7, 8, 11, 15, 16}

# %%
k1.intersection_update(k2)

# %%
k1
# Out:
# {8, 11, 16}

# %%
a = set([1, 2, 3])
b = set([2, 4, 6])
c = set([0,5,6])
d = set([2,4,5,6,12])

# %%
a.isdisjoint(b)
# Out:
# False

# %%
a.isdisjoint(c)
# Out:
# True

# %%
a.issubset(b)
# Out:
# False

# %%
b.issubset(d)
# Out:
# True

# %%
d.issuperset(b)
# Out:
# True

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 6}

# %%
a | b
# Out:
# {1, 2, 3, 4, 6}

# %%
küme = set(["elma", "armut", "kebap"])
eklenecek= [1, 2, 3]

# %%
küme.update(eklenecek)

# %%
küme
# Out:
# {1, 2, 3, 'armut', 'elma', 'kebap'}

# %%
k1
# Out:
# {8, 11, 16}

# %%
k2
# Out:
# {4, 8, 9, 11, 13, 16, 17, 19}

# %%
k1.symmetric_difference(k2)
# Out:
# {4, 9, 13, 17, 19}

# %%
k2.symmetric_difference(k1)
# Out:
# {4, 9, 13, 17, 19}

# %%
k2.pop()
# Out:
# 4
