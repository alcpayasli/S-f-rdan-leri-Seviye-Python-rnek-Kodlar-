# %% [markdown]
# # eval

# %%
veri = input('İsleminiz:')
hesap = eval(veri)
print(hesap)
# Out:
# İsleminiz:36 + 45
# 81

# %%
veri = input('İsleminiz:')
hesap = eval(veri)
print(hesap)
# Out:
# İsleminiz:3**4
# 81

# %% [markdown]
# # exec

# %%
exec("a = 45")

# %%
a
# Out:
# 45

# %%
type(a)
# Out:
# int

# %%
exec("a = 45 + 46")

# %%
a
# Out:
# 91
