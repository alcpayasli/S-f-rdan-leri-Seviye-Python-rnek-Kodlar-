# %%
# çift tırnaklla
"merhaba  dünya"
# Out:
# 'merhaba  dünya'

# %%
# tek tırnakla
'Merhaba dünya'
# Out:
# 'Merhaba dünya'

# %%
# 3 tırnakla
"""Merhaba dünya"""
# Out:
# 'Merhaba dünya'

# %%
"a"
# Out:
# 'a'

# %%
# ici bos string
''
# Out:
# ''

# %%
# bosluk barındıran string
" "
# Out:
# ' '

# %%
type('')
# Out:
# str

# %%
type("Python")
# Out:
# str

# %%
type('324')
# Out:
# str

# %%
"Python" + " " + "Programlama" + ' Dili'
# Out:
# 'Python Programlama Dili'

# %%
# veya + işaretini kullanmadan

# %%
"Python" " " "Programlama"  ' Dili'
# Out:
# 'Python Programlama Dili'

# %%
'w'*3
# Out:
# 'www'

# %%
'Python '*3
# Out:
# 'Python Python Python '

# %% [markdown]
# # Sayılar

# %%
23
# Out:
# 23

# %%
12.6
# Out:
# 12.6

# %%
12+ 5j
# Out:
# (12+5j)

# %%
5 + 2
# Out:
# 7

# %%
5 * 3
# Out:
# 15

# %%
5 / 2.5
# Out:
# 2.0

# %%
5 / 2
# Out:
# 2.5

# %%
4 / 2
# Out:
# 2.0

# %%
10 - 3
# Out:
# 7

# %%
10.0 - 3
# Out:
# 7.0

# %%
# dikkat
print(type(345))
print(type('345'))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# dikkat
print(3 + 2)
print('3' + '2')
# Out:
# 5
# 32
