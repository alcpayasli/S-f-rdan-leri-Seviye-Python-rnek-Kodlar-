# %%
kelimeler = {'kitap': 'book'}

# %%
type(kelimeler)
# Out:
# dict

# %%
len(kelimeler)
# Out:
# 1

# %%
kelimeler = {'kitap': 'book',
             'bilgisayar': 'computer'}

# %%
len(kelimeler)
# Out:
# 2

# %%
sozluk = {
    "programlama": "programming",
    "dil" : "language",
    "defter" : "notebook",
    "kitap": "book"

}

# %%
sozluk['kitap']
# Out:
# 'book'

# %%
sozluk ={"Ahmet Özkoparan": ["İstanbul","Öğretmen", 34],
         "Mehmet Yağız" :["Adana", "Mühendis", 40],
         "Seda Bayrak" : ["İskenderun","Doktor", 30]}

# %%
sozluk['Ahmet Özkoparan']
# Out:
# ['İstanbul', 'Öğretmen', 34]

# %%
kişiler ={
    "Ahmet Özkoparan": {"Memleket":"İstanbul",
                        "Meslek" : "Öğretmen",
                        "Yaş" :34},
    "MehmetYağız" :{"Memleket": "Adana",
                    "Meslek" : "Mühendis",
                    "Yaş" :40},
    "Seda Bayrak" : {"Memleket":"İskenderun",
                     "Meslek" : "Doktor",
                     "Yaş" :30}}

# %%
print(kişiler['Ahmet Özkoparan']['Memleket'])
print(kişiler['MehmetYağız']['Meslek'])
print(kişiler['Seda Bayrak']['Yaş'])
# Out:
# İstanbul
# Mühendis
# 30

# %% [markdown]
# # Sözlüğe Öge Ekleme

# %%
sozluk = {}

# %%
sozluk['book'] = 'kitap'

# %%
sozluk
# Out:
# {'book': 'kitap'}

# %%
sozluk['computer'] = 'bilgisayar'

# %%
sozluk
# Out:
# {'book': 'kitap', 'computer': 'bilgisayar'}

# %%
sozluk['Thirteen'] = 30

# %%
sozluk
# Out:
# {'book': 'kitap', 'computer': 'bilgisayar', 'Thirteen': 30}

# %%
print(sozluk)
# Out:
# {'book': 'kitap', 'computer': 'bilgisayar', 'Thirteen': 30}

# %% [markdown]
# # Ögeler Üzerinde Değişiklik

# %%
notlar = {'Seda': 98,
          'Ege': 95,
          'Mehmet': 77,
          'Zeynep': 100,
          'Deniz': 95,
          'Ahmet': 45}

# %%
notlar['Seda'] = 100

# %%
notlar
# Out:
# {'Seda': 100, 'Ege': 95, 'Mehmet': 77, 'Zeynep': 100, 'Deniz': 95, 'Ahmet': 45}

# %% [markdown]
# # Sözlük Üreteçleri

# %%
harfler = 'abcçdefgğhıijklmnoöprsştuüvyz'

# %%
sozluk = {i: harfler.index(i) for i in harfler}

# %%
sozluk
# Out:
# {'a': 0,
#  'b': 1,
#  'c': 2,
#  'ç': 3,
#  'd': 4,
#  'e': 5,
#  'f': 6,
#  'g': 7,
#  'ğ': 8,
#  'h': 9,
#  'ı': 10,
#  'i': 11,
#  'j': 12,
#  'k': 13,
#  'l': 14,
#  'm': 15,
#  'n': 16,
#  'o': 17,
#  'ö': 18,
#  'p': 19,
#  'r': 20,
#  's': 21,
#  'ş': 22,
#  't': 23,
#  'u': 24,
#  'ü': 25,
#  'v': 26,
#  'y': 27,
#  'z': 28}

# %%
isimler = ["ahmet", "mehmet", "fırat", "zeynep", "selma", "abdullah", "cem"]

# %%
sozluk = {i: len(i) for i in isimler}

# %%
sozluk
# Out:
# {'ahmet': 5,
#  'mehmet': 6,
#  'fırat': 5,
#  'zeynep': 6,
#  'selma': 5,
#  'abdullah': 8,
#  'cem': 3}

# %% [markdown]
# # Sözlük Metotları

# %%
[met for met in dir(dict) if not met.startswith('__')]
# Out:
# ['clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
sozluk
# Out:
# {'ahmet': 5,
#  'mehmet': 6,
#  'fırat': 5,
#  'zeynep': 6,
#  'selma': 5,
#  'abdullah': 8,
#  'cem': 3}

# %%
sozluk.keys()
# Out:
# dict_keys(['ahmet', 'mehmet', 'fırat', 'zeynep', 'selma', 'abdullah', 'cem'])

# %%
keys_list = list(sozluk.keys())

# %%
keys_list
# Out:
# ['ahmet', 'mehmet', 'fırat', 'zeynep', 'selma', 'abdullah', 'cem']

# %%
sozluk.values()
# Out:
# dict_values([5, 6, 5, 6, 5, 8, 3])

# %%
",".join([str(i) for i in sozluk.values()])
# Out:
# '5,6,5,6,5,8,3'

# %%
sozluk.items()
# Out:
# dict_items([('ahmet', 5), ('mehmet', 6), ('fırat', 5), ('zeynep', 6), ('selma', 5), ('abdullah', 8), ('cem', 3)])

# %%
sozluk.get('ahmet', 'bu isim bulunamadı')
# Out:
# 5

# %%
sozluk.get('can', 'bu isim bulunamadı')
# Out:
# 'bu isim bulunamadı'

# %%
sozluk.clear()

# %%
sozluk
# Out:
# {}

# %%
elemanlar = "Ahmet", "Mehmet", "Can"
adresler = dict.fromkeys(elemanlar, 'İstanbul')

# %%
adresler
# Out:
# {'Ahmet': 'İstanbul', 'Mehmet': 'İstanbul', 'Can': 'İstanbul'}

# %%
adresler.pop('Ahmet')
# Out:
# 'İstanbul'

# %%
adresler
# Out:
# {'Mehmet': 'İstanbul', 'Can': 'İstanbul'}

# %%
adresler.pop('can', 'silinecek öge yok')
# Out:
# 'silinecek öge yok'

# %%
sepet = {"meyveler": ("elma", "armut"), "sebzeler": ("pırasa", "fasulye")}

# %%
sepet.popitem()
# Out:
# ('sebzeler', ('pırasa', 'fasulye'))

# %%
sepet
# Out:
# {'meyveler': ('elma', 'armut')}

# %%
sepet.setdefault('sebzeler', ('pırasa', 'fasülye'))
# Out:
# ('pırasa', 'fasülye')

# %%
sepet
# Out:
# {'meyveler': ('elma', 'armut'), 'sebzeler': ('pırasa', 'fasülye')}

# %%
stok = {"elma": 5, "armut": 10, "peynir": 6, "sosis": 15}

# %%
yeni_stok = {"elma": 3, "armut": 20, "peynir": 8, "sosis": 4, "sucuk": 6}

# %%
stok.update(yeni_stok)

# %%
stok
# Out:
# {'elma': 3, 'armut': 20, 'peynir': 8, 'sosis': 4, 'sucuk': 6}
