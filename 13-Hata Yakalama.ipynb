# %%
sayi1 = input('Birinci sayi:')
sayi2 = input('İkinci sayi:')
try:
    sayi1 = int(sayi1)
    sayi2 = int(sayi2)
    print("{} / {}  = {}".format(sayi1,sayi2, sayi1/sayi2))
except ValueError:
    print('Sadece sayı giriniz!!!')
# Out:
# Birinci sayi:9
# İkinci sayi:6
# 9 / 6  = 1.5

# %%
sayi1 = input('Birinci sayi:')
sayi2 = input('İkinci sayi:')
try:
    sayi1 = int(sayi1)
    sayi2 = int(sayi2)
    print("{} / {}  = {}".format(sayi1,sayi2, sayi1/sayi2))
except ValueError:
    print('Sadece sayı giriniz!!!')
# Out:
# Birinci sayi:2
# İkinci sayi:.sd
# Sadece sayı giriniz!!!

# %%
sayi1 = input('Birinci sayi:')
sayi2 = input('İkinci sayi:')
try:
    sayi1 = int(sayi1)
    sayi2 = int(sayi2)
    print("{} / {}  = {}".format(sayi1,sayi2, sayi1/sayi2))
except ValueError:
    print('Sadece sayı giriniz!!!')
except ZeroDivisionError:
    print('Bir sayı 0\'a bölünemez.')
# Out:
# Birinci sayi:3
# İkinci sayi:0
# Bir sayı 0'a bölünemez.

# %%
sayi1 = input('Birinci sayi:')
sayi2 = input('İkinci sayi:')
try:
    sayi1 = int(sayi1)
    sayi2 = int(sayi2)
    print("{} / {}  = {}".format(sayi1,sayi2, sayi1/sayi2))
except (ValueError, ZeroDivisionError):
    print('Bir hata oluştu!!!')
# Out:
# Birinci sayi:4
# İkinci sayi:0
# Bir hata oluştu!!!

# %%
sayi1 = input('Birinci sayi:')
sayi2 = input('İkinci sayi:')
try:
    sayi1 = int(sayi1)
    sayi2 = int(sayi2)
    print("{} / {}  = {}".format(sayi1,sayi2, sayi1/sayi2))
except (ValueError, ZeroDivisionError):
    print('Bir hata oluştu!!!')
# Out:
# Birinci sayi:sadasd
# İkinci sayi:5
# Bir hata oluştu!!!

# %%
while True:
    sayi1 = input('Birinci sayıyı giriniz./.Çıkmak için q\'ya basınız.')
    if sayi1 == 'q':
        break
    sayi2 = input('İkinci sayi:')
    try:
        sayi1 = int(sayi1)
        sayi2 = int(sayi2)
        print("{} / {}  = {}".format(sayi1,sayi2, sayi1/sayi2))
    except (ValueError, ZeroDivisionError):
        print('Bir hata oluştu!!!')
# Out:
# Birinci sayıyı giriniz./.Çıkmak için q'ya basınız.3
# İkinci sayi:asdas
# Bir hata oluştu!!!
# Birinci sayıyı giriniz./.Çıkmak için q'ya basınız.4
# İkinci sayi:0
# Bir hata oluştu!!!
# Birinci sayıyı giriniz./.Çıkmak için q'ya basınız.4
# İkinci sayi:8
# 4 / 8  = 0.5
# Birinci sayıyı giriniz./.Çıkmak için q'ya basınız.q

# %%
sayi1 = input('Birinci sayi:')
sayi2 = input('İkinci sayi:')
try:
    sayi1 = int(sayi1)
    sayi2 = int(sayi2)
    print("{} / {}  = {}".format(sayi1,sayi2, sayi1/sayi2))
except ValueError as hata:
    print('Bir hata oluştu!!!')
    print('Orjinal hata mesajı:', hata)
# Out:
# Birinci sayi:3
# İkinci sayi:asdas
# Bir hata oluştu!!!
# Orjinal hata mesajı: invalid literal for int() with base 10: 'asdas'

# %%
sayi1 = input('Birinci sayi:')
sayi2 = input('İkinci sayi:')
try:
    sayi1 = int(sayi1)
    sayi2 = int(sayi2)
    print("{} / {}  = {}".format(sayi1,sayi2, sayi1/sayi2))
except (ValueError, ZeroDivisionError) as hata:
    print('Bir hata oluştu!!!')
    print('Orjinal hata mesajı...:', hata)
# Out:
# Birinci sayi:3
# İkinci sayi:0
# Bir hata oluştu!!!
# Orjinal hata mesajı...: division by zero

# %%
try:
    bolunen = int(input('Bölünen sayı:'))
    bolen = int(input('Bölen sayı:'))
    print('Sonuc...:', bolunen/bolen)
except ZeroDivisionError:
    print('Bölen 0 olamaz..')
except ValueError:
    print('Sadece sayı giriniz...')
# Out:
# Bölünen sayı:3
# Bölen sayı:0
# Bölen 0 olamaz..

# %%
try:
    bolunen = int(input('Bölünen sayı:'))
    bolen = int(input('Bölen sayı:'))
except ValueError:
    print('Sadece sayı giriniz...')
else:
    try:
        print('Sonuc..:', bolunen/bolen)
    except ZeroDivisionError:
        print('Bölen 0 olamaz...')
# Out:
# Bölünen sayı:4
# Bölen sayı:0
# Bölen 0 olamaz...

# %%
try:
    bolunen = int(input('Bölünen sayı:'))
    bolen = int(input('Bölen sayı:'))
    print('Sonuc...:', bolunen/bolen)
except ZeroDivisionError:
    print('Bölen 0 olamaz..')
except ValueError:
    print('Sadece sayı giriniz...')
finally:
    print('Burası her zaman çalışır.Sonuçta hatasız kod olmaz..')
# Out:
# Bölünen sayı:4
# Bölen sayı:0
# Bölen 0 olamaz..
# Burası her zaman çalışır.Sonuçta hatasız kod olmaz..

# %%
tr_karakter= "şçğüöıİ"
parola = input('Parola giriniz:')
for i in parola:
    if i in tr_karakter:
        raise Exception('Parolada türkçe karakter olamaz')
    else:
        pass
print('Parola oluşturuldu')
# Out:
# Parola giriniz:PYThön
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-15-b1341aff384d> in <cell line: 3>()
#       3 for i in parola:
#       4     if i in tr_karakter:
# ----> 5         raise Exception('Parolada türkçe karakter olamaz')
#       6     else:
#       7         pass
#
# Exception: Parolada türkçe karakter olamaz

# %%
try:
    bolunen = int(input('Bölünen sayı:'))
    bolen = int(input('Bölen sayı:'))
    print('Sonuc...:', bolunen/bolen)
except ZeroDivisionError:
    print('Bölen 0 olamaz..')
    raise
# Out:
# Bölünen sayı:12
# Bölen sayı:0
# Bölen 0 olamaz..
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-16-fe9d3b76589f> in <cell line: 1>()
#       2     bolunen = int(input('Bölünen sayı:'))
#       3     bolen = int(input('Bölen sayı:'))
# ----> 4     print('Sonuc...:', bolunen/bolen)
#       5 except ZeroDivisionError:
#       6     print('Bölen 0 olamaz..')
#
# ZeroDivisionError: division by zero

# %%
enter = input('İsmin nedir:')
if(len(enter) == 0):
    raise AssertionError('İsim boş olamaz.')
print('Hoşgeldin {}'.format(enter))
# Out:
# İsmin nedir:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-17-d2e4e309fe41> in <cell line: 2>()
#       1 enter = input('İsmin nedir:')
#       2 if(len(enter) == 0):
# ----> 3     raise AssertionError('İsim boş olamaz.')
#       4 print('Hoşgeldin {}'.format(enter))
#
# AssertionError: İsim boş olamaz.

# %%
enter = input('İsmin nedir:')
if(len(enter) == 0):
    raise AssertionError('İsim boş olamaz.')
print('Hoşgeldin {}'.format(enter))
# Out:
# İsmin nedir:ahmet
# Hoşgeldin ahmet

# %%
enter = input('İsmin nedir:')
assert len(enter)!=0, "isim boş olamaz"
print('Hoşgeldin')
# Out:
# İsmin nedir:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-97775cdd46c5> in <cell line: 2>()
#       1 enter = input('İsmin nedir:')
# ----> 2 assert len(enter)!=0, "isim boş olamaz"
#       3 print('Hoşgeldin')
#
# AssertionError: isim boş olamaz
