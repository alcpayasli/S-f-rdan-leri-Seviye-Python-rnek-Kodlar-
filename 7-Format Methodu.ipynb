# %%
print('{} kolay bir programlama dilidir.'.format('Python'))
# Out:
# Python kolay bir programlama dilidir.

# %%
metin = "{} ve {} nesne yönelimli programlama dilleridir."
print(metin.format('Python', 'Java'))
# Out:
# Python ve Java nesne yönelimli programlama dilleridir.

# %%
hata_taslagi = "{} veya {} hatalı girildi."
print(hata_taslagi.format('Parola', 'Şifre'))
# Out:
# Parola veya Şifre hatalı girildi.

# %%
isim = 'Ahmet'
soyisim = 'Candan'
yas = 32
meslek = 'Yazılımcı'
diller = 'Python, Java, C++'
print("""
Ad ve Soyad: {} {}
Meslek: {}
Yaş: {}
Diller: {}
""".format(isim, soyisim, yas, meslek, diller))
# Out:
# Ad ve Soyad: Ahmet Candan
# Meslek: 32
# Yaş: Yazılımcı
# Diller: Python, Java, C++
