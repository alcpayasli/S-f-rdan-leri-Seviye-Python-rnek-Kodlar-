# %%
demet = ('ali','veli', 33)

# %%
type(demet)
# Out:
# tuple

# %%
demet = 'ali', 'veli', 33

# %%
type(demet)
# Out:
# tuple

# %%
tuple('abcdef')
# Out:
# ('a', 'b', 'c', 'd', 'e', 'f')

# %%
tuple(['Ahmet', 'Mehmet'])
# Out:
# ('Ahmet', 'Mehmet')

# %%
tek_ogeli_demet = 'A',

# %%
type(tek_ogeli_demet)
# Out:
# tuple

# %%
tek_ogeli_demet = (33,)

# %%
type(tek_ogeli_demet)
# Out:
# tuple

# %% [markdown]
# # Ögelere Erişmek

# %%
tuple1 = ('Python', 'C', 'C++', 33, 45.67, False)

# %%
tuple1[0]
# Out:
# 'Python'

# %%
tuple1[0:3]
# Out:
# ('Python', 'C', 'C++')

# %%
tuple1+='Java',

# %%
tuple1
# Out:
# ('Python', 'C', 'C++', 33, 45.67, False, 'Java')
