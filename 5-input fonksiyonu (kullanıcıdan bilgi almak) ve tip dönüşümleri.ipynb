# %%
isim = input('İsminiz:')
print('Merhaba', isim)
# Out:
# İsminiz:Ahmet
# Merhaba Ahmet

# %%
cap = int(input('Dairenin çapını giriniz:'))
yaricap = cap / 2
alan = 3.14 * yaricap ** 2
print("Yarıçapı", yaricap, "olan dairenin alanı:", alan)
# Out:
# Dairenin çapını giriniz:6
# Yarıçapı 3.0 olan dairenin alanı: 28.26

# %% [markdown]
# # Tip Dönüşümleri

# %% [markdown]
# ##  Integer dönüşümü

# %%
a = 23
type(a)
# Out:
# int

# %%
a = 23.45
type(a)
# Out:
# float

# %%
a = '23.45'
type(a)
# Out:
# str

# %%
sayi = input('Bir sayi giriniz.')
type(sayi)
# Out:
# Bir sayi giriniz.5
# str

# %%
sayi = input('Bir sayi giriniz.')
sayi = int(sayi)
type(sayi)
# Out:
# Bir sayi giriniz.5
# int

# %%
int('5') ** 2
# Out:
# 25

# %%
'5' + '5'
# Out:
# '55'

# %%
int('5') + int('5')
# Out:
# 10

# %%
int(56.7)
# Out:
# 56

# %%
int(56.9999)
# Out:
# 56

# %% [markdown]
# ## string dönüşümü

# %%
sayi = 23
type(sayi)
# Out:
# int

# %%
sayi = str(sayi)
type(sayi)
# Out:
# str

# %%
sayi
# Out:
# '23'

# %%
sayi + sayi
# Out:
# '2323'

# %%
sayi * 5
# Out:
# '2323232323'

# %%
sayi = 123456789
len(str(sayi))
# Out:
# 9

# %% [markdown]
# ## float dönüşümü

# %%
a = 23
print(a)
# Out:
# 23

# %%
a = float(23)
print(a)
# Out:
# 23.0

# %%
b = '20'
print(b)
# Out:
# 20

# %%
b = float(b)
print(b)
# Out:
# 20.0

# %% [markdown]
# ## complex sayılar

# %%
a = 12 + 0j

# %%
type(a)
# Out:
# complex

# %%
b = 5 + 3j
type(b)
# Out:
# complex

# %%
complex(20)
# Out:
# (20+0j)
