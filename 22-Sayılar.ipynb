# %% [markdown]
# # Tam Sayıların (integer) metotları

# %%
[i for i in dir(32) if not i.startswith('__')]
# Out:
# ['as_integer_ratio',
#  'bit_count',
#  'bit_length',
#  'conjugate',
#  'denominator',
#  'from_bytes',
#  'imag',
#  'numerator',
#  'real',
#  'to_bytes']

# %%
sayi = 12

# %%
bin(sayi)
# Out:
# '0b1100'

# %%
sayi.bit_length()
# Out:
# 4

# %%
(12).bit_length()
# Out:
# 4

# %%
type(12.)
# Out:
# float

# %% [markdown]
# # Float Sayıların Metotları

# %%
[i for i in dir(float) if not i.startswith('__')]
# Out:
# ['as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %%
(4.5).as_integer_ratio()
# Out:
# (9, 2)

# %%
(12.34).as_integer_ratio()
# Out:
# (3473401212609495, 281474976710656)

# %%
(12.3).is_integer()
# Out:
# False

# %%
(12.012).is_integer()
# Out:
# False

# %%
(12.0).is_integer()
# Out:
# True

# %% [markdown]
# # Aritmetik Fonsiyonlar

# %%
abs(-2)
# Out:
# 2

# %%
abs(4)
# Out:
# 4

# %%
abs(-7.6)
# Out:
# 7.6

# %%
divmod(4,2)
# Out:
# (2, 0)

# %%
divmod(50,7)
# Out:
# (7, 1)

# %%
sayılar = [82388,260409, 72923, 692476, 131925, 259114, 47630, 84513, 25413, 614654,
           239479, 299159, 175488, 345972, 458112, 791030, 243610, 413702, 565285, 773607,
           131583, 979177, 247202, 615485, 647512, 556823, 242460, 852928, 893126, 792435,
           273904, 544434, 627222, 601984, 966446, 384143, 308858]

# %%
max(sayılar)
# Out:
# 979177

# %%
isimler =["ahmet", "mehmet", "necla", "sedat", "abdullah", "gıyaseddin","sibel", "can","necmettin", "savaş", "özgür"]

# %%
max(isimler,key = len)
# Out:
# 'gıyaseddin'

# %%
min(sayılar)
# Out:
# 25413

# %%
min(isimler, key = len)
# Out:
# 'can'

# %%
a = [12,10,4,5]

# %%
sum(a)
# Out:
# 31

# %%
sum(a,12)
# Out:
# 43
