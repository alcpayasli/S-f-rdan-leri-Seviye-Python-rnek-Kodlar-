# %%
a = 5

# %%
a
# Out:
# 5

# %%
a*3
# Out:
# 15

# %%
a / 2
# Out:
# 2.5

# %%
b = 'Python programlama dili'

# %%
b
# Out:
# 'Python programlama dili'

# %%
len(b)
# Out:
# 23

# %%
pi = 3.14
pi + a
# Out:
# 8.14

# %%
username = 'Python'
password = '12345'

# %%
len(username) + len(password)
# Out:
# 11

# %%
kullanıcı_adı_uzunluk = len(username)
sifre_uzunluk = len(password)
kullanıcı_adı_uzunluk + sifre_uzunluk
# Out:
# 11

# %% [markdown]
# # birden fazla değşkene aynı değeri atama

# %%
deg1 = deg2 = 3

# %%
print(deg1)
print(deg2)
# Out:
# 3
# 3

# %%
ocak = mart = mayıs = temmuz = ağustos= ekim =aralık = 31
nisan = haziran = eylül = kasım = 30
şubat = 28

# %%
# dairenin alanını hesaplama örneği
pi = 3.14
yaricap = 6
alan = pi * yaricap ** 2
print(alan)
# Out:
# 113.04

# %% [markdown]
# # değişken değerlerini değiştirme

# %%
# 1. yol
dil_1 = 'İngilizce'
dil_2 = 'Türkçe'
geçici = ''
geçici = dil_1
dil_1 = dil_2
dil_2 = geçici
print(dil_1)
print(dil_2)
# Out:
# Türkçe
# İngilizce

# %%
# 2. ve kısa yol
deg1 = 'Python'
deg2 = 'JAVA'
deg1, deg2 = deg2, deg1
print(deg1)
print(deg2)
# Out:
# JAVA
# Python

# %% [markdown]
# # shell hafızası

# %%
islem = 5 + 5

# %%
islem
# Out:
# 10

# %%
_
# Out:
# 10

# %%
_ + 6
# Out:
# 16

# %%
yeni_islem = _ + 12

# %%
yeni_islem
# Out:
# 28

# %%
s1 = 'Python'

# %%
s1
# Out:
# 'Python'

# %%
_
# Out:
# 'Python'

# %%
_ + ' Programlama Dili'
# Out:
# 'Python Programlama Dili'

# %%
_
# Out:
# 'Python Programlama Dili'

# %%
s1
# Out:
# 'Python'
